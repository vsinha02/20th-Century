# %%
import spacy
from spacy import displacy
#!python -m spacy download en_core-web_sm
import pandas as pd 
import numpy as np
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
NER = spacy.load("en_core_web_sm")

# %%
with open('historic_events_contents.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')

# %%
book = NER(data)
displacy.render(book[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">&quot;&quot; Bosnian
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Serbs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ' liberation movement. This was similar to how the 9/11 was the inciting incident of the 21st century.[1] Bound by
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Slavic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  nationalism to help the small
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Serbian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  state, the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  came to the aid of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Serbs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  when they were attacked.
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Interwoven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  alliances, an increasing arms race, and old hatreds dragged
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  into the war.[2] The Allies, known initially as &quot;&quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Triple Entente
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot;&quot;, comprised
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the British Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austria-Hungary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bulgaria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and later
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ottoman Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , were known as &quot;&quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Central Powers&quot;&quot;.[3][4]
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1917
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ended hostile actions against
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Central Powers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  after the fall of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tsar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bolsheviks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  negotiated
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Treaty of Brest-Litovsk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , although it was a huge cost to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In the trea

# %%
# Evaluate whether the text needs wrangling—are there any special characters used? 
# Are the names of the countries in your list the same as the names in the text? 
# Write down your observations in a markdown cell and take the necessary steps to correct any issues you’ve found. 
# If anything does need correcting, make sure you save your file as a .txt.

# %%
# Special Characters: The text includes quotation marks (""), which might need cleaning depending on your processing needs.
# There is standard punctuation such as commas, periods, and parentheses, which might also be subject to removal
# Most of the country names in the text match the country names themselves (e.g., "Germany", "France", "Russia"). However, there are some differences:
# Serbian: "Serbia" is referred to as "Serbian" and tagged as NORP instead of GPE.

# %%
df_sentences = []

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
       entity_list = [ent.text for ent in sent.ents]
       df_sentences.append({"sentence": sent, "entities": entity_list})

df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (Historic, Key, Events, ", The, 20th, century,...
# 1  (The, World, Wars, sparked, tension, between, ...
# 2  (These, advancements, have, played, a, signifi...
# 3  (Historic, events, in, the, 20th, century[edit...
# 4  (The, world, at, the, beginning, of, the, cent...
# 5  (The, 1900s, saw, the, decade, herald, a, seri...
# 6  (From, 1914, to, 1918, ,, the, First, World, W...
# 7  (", ", The, war, to, end, all, wars, ", ", :, ...
# 8  (Main, article, :, World, War, I, Arrest, of, ...
# 9  (The, war, and, by, extension, the, century, a...
#
#                                             entities
# 0                   [Historic Key, The 20th century]
# 1  [the Cold War, the Space Race, the World Wide ...
# 2                          [the 21st century, today]
# 3                                             [20th]
# 4                                 [the 20th century]
# 5                            [The 1900s, the decade]
# 6                [1914 to 1918, the First World War]
# 7                                      [World War I]
# 8  [Main, World War I Arrest, Sarajevo, the Assas...
# 9  [the century, Sarajevo, the Austro-Hungarian E...

# %%
country_df = pd.read_csv('../documents/workspace/Countries-Occurences.txt', sep='\t')

# %%
def filter_entity(ent_list, country_df):
       return [ent for ent in ent_list
                  if ent in list(country_df['Country'])]
print(country_df.columns)
# Out:
# Index(['Country', 'Occurrences'], dtype='object')

# %%
df_sentences['Country'] = df_sentences['entities'].apply(lambda x: filter_entity(x, country_df))

# %%
df_sentences_filtered = df_sentences[df_sentences['Country'].map(len) > 0]

df_sentences_filtered.tail(10)
# Out:
#                                                sentence  \
# 1126  (^, ", ", Major, milestones, of, Iran, 's, nuc...
# 1136  (^, ", ", The, division, of, Germany, -, The, ...
# 1165  (", ", The, forgotten, violence, that, helped,...
# 1169  (", ", Indian, Independence, Day, :, everythin...
# 1246  (The, Moldovans, :, Romania, ,, Russia, ,, and...
# 1259  (Now, ,, North, Korea, may, be, the, one, true...
# 1309  (", ", Selling, ", ", Operation, Passage, to, ...
# 1342  (", ", Stuck, in, Endless, Preliminaries, :, V...
# 1602  (The, Rise, of, China, and, India, :, A, New, ...
# 1603               (Singapore, :, World, Scientific, .)
#
#                                                entities            Country
# 1126                           [Iran, Iran, Al Jazeera]       [Iran, Iran]
# 1136                 [Germany, The Cold War, 1945–1989]          [Germany]
# 1165                                            [India]            [India]
# 1169  [Indian Independence Day: everything you, Part...  [India, Pakistan]
# 1246  [Moldovans, Romania, Russia, the Politics of C...  [Romania, Russia]
# 1259                                 [North Korea, one]      [North Korea]
# 1309  [Operation Passage to Freedom, Thomas Dooley, ...          [Vietnam]
# 1342  [Stuck in Endless Preliminaries:, Vietnam, the...          [Vietnam]
# 1602                    [China, India, New Asian Drama]            [India]
# 1603                      [Singapore, World Scientific]        [Singapore]

# %%
# Defining relationships

# window size = 5 : this defines how many sentences will be looked at simultaneously
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
     end_i = min(i+5, df_sentences_filtered.index[-1])
     char_list = sum((df_sentences_filtered.loc[i: end_i].Country), [])

     # Remove duplicated characters that are next to each other
     char_unique = [char_list[i] for i in range(len(char_list))
                             if (i==0) or char_list[i] != char_list[i-1]]

     if len(char_unique) > 1:
        for idx, a in enumerate( char_unique[ :-1]):
          b = char_unique[idx + 1]
          relationships.append({"source": a, " target": b})

# %%
relationship_df = pd.DataFrame(relationships)

relationship_df
# Out:
#       source     target
# 0     France     Russia
# 1     France     Russia
# 2     Russia    Germany
# 3    Germany   Bulgaria
# 4     France     Russia
# ..       ...        ...
# 575    India  Singapore
# 576    India  Singapore
# 577    India  Singapore
# 578    India  Singapore
# 579    India  Singapore
#
# [580 rows x 2 columns]

# %%
relationship_df.to_csv('../documents/workspace/Relationship_Dataframe.txt', sep='\t', index=False)
